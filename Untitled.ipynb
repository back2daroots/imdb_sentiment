# %%
import pandas as pd

# %%
path = '/users/rutz/Documents/PROG/mentor/imdb/data/IMDB_Dataset.csv'

# %%
df = pd.read_csv(path)

# %%
df['sentiment'].value_counts()
# Out:
# positive    25000
# negative    25000
# Name: sentiment, dtype: int64
